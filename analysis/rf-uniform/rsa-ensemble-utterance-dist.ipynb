# %% [markdown]
# # Setup

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import json
import pandas as pd

# %%
ROOT_DIR = '../../'
import sys
sys.path.insert(0, ROOT_DIR)

import eval_utils

# %% [markdown]
# ## Define models to eval

# %%
EVAL_DATASET = 'rf-uniform'
MODEL_TYPE = 'rsa_ensemble'

# %%
eval_results = eval_utils.load_eval_results(EVAL_DATASET, MODEL_TYPE, listener_types=['val'])

# %% [markdown]
# # Vocab Distribution

# %%
listener_type = 'val' # pick 'val' since there's only one val listener regardless of speaker type; when there are multiple listeners there are nested dicts in `eval_results`
vocab_dist = [eval_utils.analyze_vocab_dist(curr_speaker_results[listener_type], curr_speaker_results['all_referents']) for curr_speaker_results in eval_results]

# %%
dist_per_speaker = [vocab_dist_per_speaker['utterance_type'] for vocab_dist_per_speaker in vocab_dist]

# %%
eval_utils.visualize_utterance_distribution(dist_per_speaker)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %% [markdown]
# ### When target is red circle

# %%
red_circle_dist = [eval_utils.analyze_vocab_dist(curr_speaker_results[listener_type], curr_speaker_results['all_referents'], lambda x: x[0] == 'red' and x[1] == 'circle') for curr_speaker_results in eval_results]
red_circle_dist_per_speaker = [vocab_dist_per_speaker['utterance_type'] for vocab_dist_per_speaker in red_circle_dist]
eval_utils.visualize_utterance_distribution(red_circle_dist_per_speaker)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %% [markdown]
# ### Target is non-red circle

# %%
nonred_circle_dist = [eval_utils.analyze_vocab_dist(curr_speaker_results[listener_type], curr_speaker_results['all_referents'], lambda x: x[0] != 'red' and x[1] == 'circle') for curr_speaker_results in eval_results]
nonred_circle_dist_per_speaker = [vocab_dist_per_speaker['utterance_type'] for vocab_dist_per_speaker in nonred_circle_dist]
eval_utils.visualize_utterance_distribution(nonred_circle_dist_per_speaker)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %% [markdown]
# ### Target is red non-circle

# %%
red_noncircle_dist = [eval_utils.analyze_vocab_dist(curr_speaker_results[listener_type], curr_speaker_results['all_referents'], lambda x: x[0] == 'red' and x[1] != 'circle') for curr_speaker_results in eval_results]
red_noncircle_dist_per_speaker = [vocab_dist_per_speaker['utterance_type'] for vocab_dist_per_speaker in red_noncircle_dist]
eval_utils.visualize_utterance_distribution(red_noncircle_dist_per_speaker)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %% [markdown]
# ### Target is neither red nor circle

# %%
nonred_noncircle_dist = [eval_utils.analyze_vocab_dist(curr_speaker_results[listener_type], curr_speaker_results['all_referents'], lambda x: x[0] != 'red' and x[1] != 'circle') for curr_speaker_results in eval_results]
nonred_noncircle_dist_per_speaker = [vocab_dist_per_speaker['utterance_type'] for vocab_dist_per_speaker in nonred_noncircle_dist]
eval_utils.visualize_utterance_distribution(nonred_noncircle_dist_per_speaker)
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %% [markdown]
# # Accuracy

# %% [markdown]
# ## Val listener

# %%
val_accuracy_per_speaker = [eval_utils.analyze_accuracy(curr_speaker_results['val'], curr_speaker_results['all_referents']) for curr_speaker_results in eval_results]
# Out:
# ../../eval_utils.py:326: RuntimeWarning: invalid value encountered in true_divide
#   incorrect_mean_maxprob_by_config /= num_incorrect_by_config

# %%
[val_accuracy['overall_accuracy'] for val_accuracy in val_accuracy_per_speaker]
# Out:
# [0.94285, 0.94555, 0.9446, 0.9452, 0.94435]

# %%
val_accuracy_per_speaker_by_condition = {}
for context in val_accuracy_per_speaker[0]['accuracy_by_context']:
    curr_context_acc = np.asarray([val_accuracy['accuracy_by_context'][context] for val_accuracy in val_accuracy_per_speaker])
    val_accuracy_per_speaker_by_condition[context] = curr_context_acc

aggregate_val_accuracy_by_condition = {condition: (np.mean(accs).round(4), np.std(accs).round(4)) for condition, accs in val_accuracy_per_speaker_by_condition.items()}

aggregate_val_accuracy_by_condition # each tuple is (mean, std)
# Out:
# {'both-needed': (0.9043, 0.002),
#  'either-okay': (0.9991, 0.0002),
#  'shape-needed': (0.8756, 0.0034),
#  'color-needed': (0.999, 0.0001)}

# %% [markdown]
# # QA

# %%
from collections import Counter

# %%
speaker_idx = 0 # only looking at 1 speaker

shape_qa = eval_utils.qualitative_analysis('shape-needed', eval_results[speaker_idx]['val'], eval_results[speaker_idx]['all_referents'], num_examples=-1)
color_qa = eval_utils.qualitative_analysis('color-needed', eval_results[speaker_idx]['val'], eval_results[speaker_idx]['all_referents'], num_examples=-1)
either_qa = eval_utils.qualitative_analysis('either-okay', eval_results[speaker_idx]['val'], eval_results[speaker_idx]['all_referents'], num_examples=-1)

# %%
shape_qa
# Out:
# [{'pred': 0,
#   'referents': ['green ellipse', 'green rectangle', 'green square'],
#   'utterance': 'green ellipse',
#   'sem': array([0.999, 0.   , 0.002], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white square', 'white ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([0.999, 0.018, 0.   ], dtype=float32),
#   'probs': array([0.574, 0.215, 0.211], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green rectangle', 'green square'],
#   'utterance': 'circle',
#   'sem': array([0.96, 0.  , 0.  ], dtype=float32),
#   'probs': array([0.566, 0.217, 0.217], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red square', 'red ellipse'],
#   'utterance': 'circle',
#   'sem': array([1.  , 0.  , 0.05], dtype=float32),
#   'probs': array([0.57, 0.21, 0.22], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow square', 'yellow circle'],
#   'utterance': 'ellipse',
#   'sem': array([1.   , 0.   , 0.037], dtype=float32),
#   'probs': array([0.572, 0.21 , 0.218], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue rectangle', 'blue square'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.003, 0.999], dtype=float32),
#   'probs': array([0.422, 0.156, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue ellipse', 'blue circle'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow circle', 'yellow rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([1.   , 0.969, 0.   ], dtype=float32),
#   'probs': array([0.428, 0.415, 0.157], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red square', 'red ellipse'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.   , 0.003], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green ellipse', 'green rectangle'],
#   'utterance': 'green square',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow square', 'yellow rectangle'],
#   'utterance': 'yellow circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green rectangle', 'green circle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.311, 0.   ], dtype=float32),
#   'probs': array([0.535, 0.269, 0.197], dtype=float32)},
#  {'pred': 2,
#   'referents': ['green ellipse', 'green square', 'green circle'],
#   'utterance': 'green circle',
#   'sem': array([0.986, 0.034, 1.   ], dtype=float32),
#   'probs': array([0.417, 0.161, 0.423], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue square', 'blue ellipse'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.031, 1.   ], dtype=float32),
#   'probs': array([0.42 , 0.159, 0.42 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green circle', 'green ellipse'],
#   'utterance': 'green rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray rectangle', 'gray square'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.   , 0.001], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'white rectangle', 'white circle'],
#   'utterance': 'square',
#   'sem': array([0.873, 0.664, 0.   ], dtype=float32),
#   'probs': array([0.448, 0.364, 0.187], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'red square', 'red rectangle'],
#   'utterance': 'red ellipse',
#   'sem': array([1.   , 0.   , 0.005], dtype=float32),
#   'probs': array([0.575, 0.212, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow square', 'yellow circle'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.001, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white square', 'white circle'],
#   'utterance': 'white rectangle',
#   'sem': array([1.   , 0.739, 0.   ], dtype=float32),
#   'probs': array([0.468, 0.36 , 0.172], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red circle', 'red square'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white square', 'white circle'],
#   'utterance': 'white ellipse',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 1,
#   'referents': ['white circle', 'white ellipse', 'white square'],
#   'utterance': 'circle',
#   'sem': array([0.049, 0.691, 0.   ], dtype=float32),
#   'probs': array([0.26 , 0.493, 0.247], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white circle', 'white square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.999], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red circle', 'red rectangle'],
#   'utterance': 'square',
#   'sem': array([0.991, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.574, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green circle', 'green ellipse'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white ellipse', 'white square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.999], dtype=float32),
#   'probs': array([0.423, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red rectangle', 'red circle'],
#   'utterance': 'square',
#   'sem': array([0.23, 0.  , 0.  ], dtype=float32),
#   'probs': array([0.386, 0.307, 0.307], dtype=float32)},
#  {'pred': 2,
#   'referents': ['yellow ellipse', 'yellow rectangle', 'yellow circle'],
#   'utterance': 'yellow circle',
#   'sem': array([0.698, 0.   , 0.99 ], dtype=float32),
#   'probs': array([0.352, 0.175, 0.472], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray circle', 'gray ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue ellipse', 'blue rectangle'],
#   'utterance': 'square',
#   'sem': array([0.091, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.354, 0.323, 0.323], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white rectangle', 'white square'],
#   'utterance': 'white circle',
#   'sem': array([0.085, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.352, 0.324, 0.324], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white rectangle', 'white circle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow square', 'yellow circle'],
#   'utterance': 'yellow ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red square', 'red ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.999, 0.   ], dtype=float32),
#   'probs': array([0.423, 0.422, 0.155], dtype=float32)},
#  {'pred': 2,
#   'referents': ['green circle', 'green rectangle', 'green square'],
#   'utterance': 'green ellipse',
#   'sem': array([0.006, 0.012, 0.769], dtype=float32),
#   'probs': array([0.241, 0.242, 0.517], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow square', 'yellow rectangle'],
#   'utterance': 'yellow circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white circle', 'white ellipse'],
#   'utterance': 'white rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white square', 'white rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray circle', 'gray rectangle'],
#   'utterance': 'square',
#   'sem': array([1.  , 0.  , 0.61], dtype=float32),
#   'probs': array([0.489, 0.18 , 0.331], dtype=float32)},
#  {'pred': 1,
#   'referents': ['red circle', 'red ellipse', 'red rectangle'],
#   'utterance': 'red circle',
#   'sem': array([0.001, 0.005, 0.   ], dtype=float32),
#   'probs': array([0.333, 0.334, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green rectangle', 'green square'],
#   'utterance': 'green ellipse',
#   'sem': array([1.   , 0.   , 0.004], dtype=float32),
#   'probs': array([0.576, 0.212, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green circle', 'green square'],
#   'utterance': 'green square',
#   'sem': array([0.585, 0.119, 0.068], dtype=float32),
#   'probs': array([0.45 , 0.282, 0.268], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'white circle', 'white rectangle'],
#   'utterance': 'white square',
#   'sem': array([1.   , 0.097, 0.967], dtype=float32),
#   'probs': array([0.421, 0.171, 0.408], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray rectangle', 'gray circle'],
#   'utterance': 'square',
#   'sem': array([0.997, 0.189, 0.   ], dtype=float32),
#   'probs': array([0.551, 0.246, 0.203], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue ellipse', 'blue circle', 'blue rectangle'],
#   'utterance': 'blue ellipse',
#   'sem': array([1.   , 0.997, 0.   ], dtype=float32),
#   'probs': array([0.423, 0.421, 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'red rectangle', 'red circle'],
#   'utterance': 'red circle',
#   'sem': array([0.713, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.505, 0.247, 0.248], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red circle', 'red ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red ellipse', 'red square'],
#   'utterance': 'circle',
#   'sem': array([0.996, 0.995, 0.   ], dtype=float32),
#   'probs': array([0.422, 0.422, 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green ellipse', 'green circle'],
#   'utterance': 'green rectangle',
#   'sem': array([1.   , 0.001, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray rectangle', 'gray square'],
#   'utterance': 'circle',
#   'sem': array([0.257, 0.   , 0.006], dtype=float32),
#   'probs': array([0.392, 0.303, 0.305], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white square', 'white ellipse'],
#   'utterance': 'white rectangle',
#   'sem': array([0.957, 0.075, 0.   ], dtype=float32),
#   'probs': array([0.556, 0.23 , 0.214], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green circle', 'green square'],
#   'utterance': 'green rectangle',
#   'sem': array([1.   , 0.007, 0.   ], dtype=float32),
#   'probs': array([0.575, 0.213, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray ellipse', 'gray rectangle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.999], dtype=float32),
#   'probs': array([0.423, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray square', 'gray rectangle'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red circle', 'red rectangle'],
#   'utterance': 'red square',
#   'sem': array([1.   , 0.947, 0.071], dtype=float32),
#   'probs': array([0.427, 0.405, 0.169], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow rectangle'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.885, 0.   ], dtype=float32),
#   'probs': array([0.443, 0.395, 0.163], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white square', 'white rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow rectangle', 'yellow ellipse'],
#   'utterance': 'square',
#   'sem': array([0.991, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.574, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green circle', 'green rectangle'],
#   'utterance': 'square',
#   'sem': array([0.983, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.572, 0.214, 0.214], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow square', 'yellow circle'],
#   'utterance': 'yellow ellipse',
#   'sem': array([1.   , 0.   , 0.889], dtype=float32),
#   'probs': array([0.442, 0.163, 0.395], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'red circle', 'red square'],
#   'utterance': 'red ellipse',
#   'sem': array([1.   , 0.784, 0.012], dtype=float32),
#   'probs': array([0.459, 0.37 , 0.171], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray square', 'gray rectangle'],
#   'utterance': 'gray circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 2,
#   'referents': ['yellow ellipse', 'yellow rectangle', 'yellow circle'],
#   'utterance': 'yellow ellipse',
#   'sem': array([0.003, 0.   , 0.998], dtype=float32),
#   'probs': array([0.213, 0.212, 0.575], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'red square', 'red circle'],
#   'utterance': 'ellipse',
#   'sem': array([0.998, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 1,
#   'referents': ['yellow ellipse', 'yellow circle', 'yellow square'],
#   'utterance': 'yellow ellipse',
#   'sem': array([0.964, 1.   , 0.   ], dtype=float32),
#   'probs': array([0.414, 0.429, 0.158], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray rectangle', 'gray square'],
#   'utterance': 'gray circle',
#   'sem': array([0.997, 0.   , 0.01 ], dtype=float32),
#   'probs': array([0.574, 0.212, 0.214], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray square', 'gray rectangle'],
#   'utterance': 'gray circle',
#   'sem': array([0.994, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.575, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white ellipse', 'white circle'],
#   'utterance': 'white rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 1,
#   'referents': ['gray square', 'gray rectangle', 'gray ellipse'],
#   'utterance': 'square',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 2,
#   'referents': ['blue circle', 'blue ellipse', 'blue rectangle'],
#   'utterance': 'blue',
#   'sem': array([0.995, 1.   , 1.   ], dtype=float32),
#   'probs': array([0.332, 0.334, 0.334], dtype=float32)},
#  {'pred': 1,
#   'referents': ['green ellipse', 'green circle', 'green square'],
#   'utterance': 'green circle',
#   'sem': array([0.436, 0.999, 0.022], dtype=float32),
#   'probs': array([0.293, 0.514, 0.193], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray square', 'gray rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([0.999, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 2,
#   'referents': ['red square', 'red ellipse', 'red rectangle'],
#   'utterance': 'red rectangle',
#   'sem': array([0.912, 0.063, 1.   ], dtype=float32),
#   'probs': array([0.397, 0.17 , 0.433], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green circle', 'green ellipse'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue square', 'blue ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([0.081, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.352, 0.324, 0.324], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white circle', 'white square'],
#   'utterance': 'white ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray square', 'gray circle'],
#   'utterance': 'ellipse',
#   'sem': array([1.   , 0.   , 0.029], dtype=float32),
#   'probs': array([0.573, 0.211, 0.217], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red circle', 'red rectangle'],
#   'utterance': 'rectangle',
#   'sem': array([0.977, 0.   , 0.856], dtype=float32),
#   'probs': array([0.442, 0.166, 0.392], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue rectangle', 'blue circle'],
#   'utterance': 'blue square',
#   'sem': array([1.   , 0.238, 0.055], dtype=float32),
#   'probs': array([0.539, 0.252, 0.21 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow circle', 'yellow ellipse'],
#   'utterance': 'yellow square',
#   'sem': array([0.997, 0.   , 0.165], dtype=float32),
#   'probs': array([0.554, 0.204, 0.241], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red rectangle', 'red ellipse'],
#   'utterance': 'red circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white square', 'white rectangle'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green square', 'green circle'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green ellipse', 'green square'],
#   'utterance': 'ellipse',
#   'sem': array([0.991, 0.336, 0.   ], dtype=float32),
#   'probs': array([0.529, 0.275, 0.196], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green circle', 'green rectangle'],
#   'utterance': 'green ellipse',
#   'sem': array([1.   , 0.97 , 0.979], dtype=float32),
#   'probs': array([0.339, 0.329, 0.332], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow square'],
#   'utterance': 'circle',
#   'sem': array([0.439, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.437, 0.282, 0.282], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue circle', 'blue ellipse'],
#   'utterance': 'blue square',
#   'sem': array([0.023, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.338, 0.331, 0.331], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white circle', 'white ellipse'],
#   'utterance': 'white rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green rectangle', 'green square'],
#   'utterance': 'green circle',
#   'sem': array([0.976, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.57 , 0.215, 0.215], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow square', 'yellow circle'],
#   'utterance': 'ellipse',
#   'sem': array([0.997, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.575, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white circle', 'white ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 1,
#   'referents': ['gray circle', 'gray ellipse', 'gray square'],
#   'utterance': 'gray circle',
#   'sem': array([0.981, 0.991, 0.001], dtype=float32),
#   'probs': array([0.419, 0.424, 0.157], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray square', 'gray circle'],
#   'utterance': 'ellipse',
#   'sem': array([0.8  , 0.   , 0.005], dtype=float32),
#   'probs': array([0.526, 0.236, 0.238], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'white rectangle', 'white ellipse'],
#   'utterance': 'white square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red ellipse', 'red square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green ellipse', 'green circle'],
#   'utterance': 'rectangle',
#   'sem': array([0.013, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.336, 0.332, 0.332], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow circle', 'yellow ellipse'],
#   'utterance': 'yellow square',
#   'sem': array([0.959, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.566, 0.217, 0.217], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow circle', 'yellow square'],
#   'utterance': 'rectangle',
#   'sem': array([0.999, 0.   , 0.873], dtype=float32),
#   'probs': array([0.444, 0.164, 0.392], dtype=float32)},
#  {'pred': 2,
#   'referents': ['white ellipse', 'white rectangle', 'white circle'],
#   'utterance': 'white ellipse',
#   'sem': array([1.   , 0.004, 1.   ], dtype=float32),
#   'probs': array([0.422, 0.156, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green ellipse', 'green square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.093], dtype=float32),
#   'probs': array([0.564, 0.208, 0.228], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green rectangle', 'green square'],
#   'utterance': 'circle',
#   'sem': array([0.195, 0.   , 0.006], dtype=float32),
#   'probs': array([0.377, 0.31 , 0.312], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow ellipse', 'yellow rectangle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green ellipse', 'green square'],
#   'utterance': 'circle',
#   'sem': array([0.979, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.571, 0.214, 0.215], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue ellipse', 'blue square'],
#   'utterance': 'rectangle',
#   'sem': array([0.966, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.568, 0.216, 0.216], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow circle', 'yellow ellipse'],
#   'utterance': 'yellow rectangle',
#   'sem': array([0.994, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.575, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue rectangle', 'blue circle'],
#   'utterance': 'blue square',
#   'sem': array([0.999, 0.577, 0.   ], dtype=float32),
#   'probs': array([0.494, 0.324, 0.182], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray ellipse', 'gray rectangle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.938], dtype=float32),
#   'probs': array([0.433, 0.159, 0.407], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue rectangle', 'blue circle'],
#   'utterance': 'blue square',
#   'sem': array([1.   , 0.002, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green square', 'green rectangle'],
#   'utterance': 'green ellipse',
#   'sem': array([1.   , 0.   , 0.016], dtype=float32),
#   'probs': array([0.574, 0.211, 0.215], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray ellipse', 'gray rectangle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.998], dtype=float32),
#   'probs': array([0.423, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow square', 'yellow circle'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green circle', 'green rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([0.789, 0.497, 0.032], dtype=float32),
#   'probs': array([0.451, 0.337, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow ellipse', 'yellow circle'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow square', 'yellow circle'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.069, 0.   ], dtype=float32),
#   'probs': array([0.568, 0.224, 0.209], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow square', 'yellow circle'],
#   'utterance': 'ellipse',
#   'sem': array([1.   , 0.   , 0.114], dtype=float32),
#   'probs': array([0.562, 0.207, 0.232], dtype=float32)},
#  {'pred': 2,
#   'referents': ['yellow circle', 'yellow square', 'yellow ellipse'],
#   'utterance': 'yellow ellipse',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'white ellipse', 'white rectangle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow ellipse', 'yellow circle'],
#   'utterance': 'yellow rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow square', 'yellow ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.932, 0.   ], dtype=float32),
#   'probs': array([0.434, 0.406, 0.16 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green circle', 'green rectangle'],
#   'utterance': 'green square',
#   'sem': array([0.999, 0.   , 0.619], dtype=float32),
#   'probs': array([0.487, 0.179, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray circle', 'gray ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green square', 'green rectangle'],
#   'utterance': 'green ellipse',
#   'sem': array([1.   , 0.   , 0.018], dtype=float32),
#   'probs': array([0.574, 0.211, 0.215], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray circle', 'gray ellipse'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue circle', 'blue rectangle'],
#   'utterance': 'square',
#   'sem': array([0.946, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.563, 0.219, 0.219], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green rectangle', 'green square'],
#   'utterance': 'circle',
#   'sem': array([0.057, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.346, 0.327, 0.327], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray square', 'gray rectangle'],
#   'utterance': 'gray circle',
#   'sem': array([0.994, 0.024, 0.   ], dtype=float32),
#   'probs': array([0.572, 0.217, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue ellipse', 'blue square', 'blue circle'],
#   'utterance': 'blue ellipse',
#   'sem': array([1.   , 0.023, 0.229], dtype=float32),
#   'probs': array([0.544, 0.205, 0.251], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray circle', 'gray rectangle'],
#   'utterance': 'gray ellipse',
#   'sem': array([1.   , 0.998, 0.   ], dtype=float32),
#   'probs': array([0.423, 0.422, 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white ellipse', 'white rectangle'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray ellipse', 'gray rectangle'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.969, 0.   ], dtype=float32),
#   'probs': array([0.428, 0.415, 0.157], dtype=float32)},
#  {'pred': 1,
#   'referents': ['white circle', 'white ellipse', 'white rectangle'],
#   'utterance': 'circle',
#   'sem': array([0.015, 0.956, 0.   ], dtype=float32),
#   'probs': array([0.22 , 0.564, 0.217], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red circle', 'red ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 1,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow square'],
#   'utterance': 'circle',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red square', 'red ellipse'],
#   'utterance': 'red circle',
#   'sem': array([0.994, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.575, 0.213, 0.213], dtype=float32)},
#  {'pred': 2,
#   'referents': ['red ellipse', 'red square', 'red circle'],
#   'utterance': 'ellipse',
#   'sem': array([0.907, 0.   , 1.   ], dtype=float32),
#   'probs': array([0.4  , 0.161, 0.439], dtype=float32)},
#  {'pred': 1,
#   'referents': ['green square', 'green rectangle', 'green ellipse'],
#   'utterance': 'square',
#   'sem': array([0.412, 0.951, 0.   ], dtype=float32),
#   'probs': array([0.296, 0.508, 0.196], dtype=float32)},
#  {'pred': 2,
#   'referents': ['blue circle', 'blue rectangle', 'blue ellipse'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.625, 1.   ], dtype=float32),
#   'probs': array([0.372, 0.256, 0.372], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray ellipse', 'gray square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.998], dtype=float32),
#   'probs': array([0.423, 0.155, 0.422], dtype=float32)},
#  {'pred': 1,
#   'referents': ['white circle', 'white ellipse', 'white square'],
#   'utterance': 'circle',
#   'sem': array([0.49 , 0.997, 0.   ], dtype=float32),
#   'probs': array([0.305, 0.507, 0.187], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green ellipse', 'green circle'],
#   'utterance': 'green square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray square', 'gray circle'],
#   'utterance': 'gray ellipse',
#   'sem': array([1.   , 0.   , 0.636], dtype=float32),
#   'probs': array([0.485, 0.178, 0.337], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow square', 'yellow rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray circle', 'gray ellipse'],
#   'utterance': 'gray square',
#   'sem': array([0.864, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.543, 0.229, 0.229], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow square', 'yellow ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.811, 0.   ], dtype=float32),
#   'probs': array([0.455, 0.377, 0.168], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue rectangle', 'blue circle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.031, 0.   ], dtype=float32),
#   'probs': array([0.572, 0.217, 0.211], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white square', 'white circle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green ellipse', 'green rectangle'],
#   'utterance': 'circle',
#   'sem': array([0.946, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.563, 0.219, 0.219], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow square', 'yellow ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.996, 0.   ], dtype=float32),
#   'probs': array([0.423, 0.421, 0.156], dtype=float32)},
#  {'pred': 1,
#   'referents': ['red ellipse', 'red circle', 'red square'],
#   'utterance': 'red circle',
#   'sem': array([0.988, 1.   , 0.   ], dtype=float32),
#   'probs': array([0.419, 0.424, 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red rectangle', 'red circle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.002, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green circle', 'green rectangle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.992], dtype=float32),
#   'probs': array([0.424, 0.156, 0.42 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green circle', 'green ellipse'],
#   'utterance': 'green square',
#   'sem': array([0.89 , 0.   , 0.005], dtype=float32),
#   'probs': array([0.548, 0.225, 0.226], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow ellipse', 'yellow rectangle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.001], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow square'],
#   'utterance': 'circle',
#   'sem': array([0., 0., 0.], dtype=float32),
#   'probs': array([0.333, 0.333, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow ellipse', 'yellow rectangle'],
#   'utterance': 'yellow square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white square', 'white circle'],
#   'utterance': 'white ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow circle', 'yellow square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.111], dtype=float32),
#   'probs': array([0.562, 0.207, 0.231], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow circle', 'yellow rectangle'],
#   'utterance': 'yellow square',
#   'sem': array([1.   , 0.001, 0.958], dtype=float32),
#   'probs': array([0.43 , 0.158, 0.412], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green ellipse', 'green rectangle'],
#   'utterance': 'green circle',
#   'sem': array([1.   , 0.084, 0.   ], dtype=float32),
#   'probs': array([0.566, 0.226, 0.208], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red ellipse', 'red circle'],
#   'utterance': 'red rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green circle', 'green ellipse'],
#   'utterance': 'green rectangle',
#   'sem': array([0.297, 0.   , 0.003], dtype=float32),
#   'probs': array([0.402, 0.299, 0.299], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white ellipse', 'white square'],
#   'utterance': 'white rectangle',
#   'sem': array([1.   , 0.004, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.213, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow rectangle'],
#   'utterance': 'yellow circle',
#   'sem': array([1.   , 0.379, 0.   ], dtype=float32),
#   'probs': array([0.525, 0.282, 0.193], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white square', 'white circle'],
#   'utterance': 'white rectangle',
#   'sem': array([1.   , 0.782, 0.   ], dtype=float32),
#   'probs': array([0.46 , 0.37 , 0.169], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue ellipse', 'blue square'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.283, 0.056], dtype=float32),
#   'probs': array([0.533, 0.26 , 0.207], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white square', 'white rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray rectangle', 'gray circle'],
#   'utterance': 'ellipse',
#   'sem': array([0.638, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.486, 0.257, 0.257], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'red rectangle', 'red square'],
#   'utterance': 'red ellipse',
#   'sem': array([1.   , 0.   , 0.062], dtype=float32),
#   'probs': array([0.568, 0.209, 0.222], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green rectangle', 'green circle'],
#   'utterance': 'ellipse',
#   'sem': array([1.   , 0.   , 0.009], dtype=float32),
#   'probs': array([0.575, 0.212, 0.214], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow rectangle', 'yellow circle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red square', 'red ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([0.011, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.336, 0.332, 0.332], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue ellipse', 'blue square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.433], dtype=float32),
#   'probs': array([0.517, 0.19 , 0.293], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray rectangle', 'gray circle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray square', 'gray ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([1.   , 0.   , 0.101], dtype=float32),
#   'probs': array([0.563, 0.207, 0.229], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white square', 'white circle'],
#   'utterance': 'white rectangle',
#   'sem': array([1.  , 0.78, 0.  ], dtype=float32),
#   'probs': array([0.461, 0.37 , 0.17 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray ellipse', 'gray square'],
#   'utterance': 'rectangle',
#   'sem': array([0.952, 0.   , 0.91 ], dtype=float32),
#   'probs': array([0.427, 0.165, 0.409], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red circle', 'red rectangle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white rectangle', 'white ellipse'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue ellipse', 'blue rectangle'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.992, 0.001], dtype=float32),
#   'probs': array([0.424, 0.42 , 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray circle', 'gray square'],
#   'utterance': 'gray rectangle',
#   'sem': array([0.999, 0.   , 0.532], dtype=float32),
#   'probs': array([0.501, 0.185, 0.314], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue ellipse', 'blue rectangle', 'blue square'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.   , 0.911], dtype=float32),
#   'probs': array([0.438, 0.161, 0.401], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green ellipse', 'green rectangle'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.015, 0.   ], dtype=float32),
#   'probs': array([0.574, 0.214, 0.211], dtype=float32)},
#  {'pred': 1,
#   'referents': ['yellow square', 'yellow rectangle', 'yellow ellipse'],
#   'utterance': 'square',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red square', 'red circle'],
#   'utterance': 'rectangle',
#   'sem': array([0.998, 0.526, 0.   ], dtype=float32),
#   'probs': array([0.502, 0.313, 0.185], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'red square', 'red rectangle'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.001, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray square', 'gray circle'],
#   'utterance': 'rectangle',
#   'sem': array([0.998, 0.032, 0.   ], dtype=float32),
#   'probs': array([0.572, 0.218, 0.211], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue circle', 'blue ellipse'],
#   'utterance': 'blue square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray rectangle', 'gray circle'],
#   'utterance': 'ellipse',
#   'sem': array([0.149, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.367, 0.316, 0.316], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red square', 'red circle'],
#   'utterance': 'red square',
#   'sem': array([1.   , 1.   , 0.001], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'white ellipse', 'white rectangle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.002], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green circle', 'green ellipse'],
#   'utterance': 'green rectangle',
#   'sem': array([0.971, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.569, 0.216, 0.216], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green circle', 'green square'],
#   'utterance': 'rectangle',
#   'sem': array([0.994, 0.   , 0.077], dtype=float32),
#   'probs': array([0.565, 0.209, 0.226], dtype=float32)},
#  {'pred': 1,
#   'referents': ['gray rectangle', 'gray square', 'gray ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([0.176, 0.703, 0.001], dtype=float32),
#   'probs': array([0.283, 0.48 , 0.237], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray circle', 'gray ellipse'],
#   'utterance': 'gray rectangle',
#   'sem': array([0.999, 0.   , 0.166], dtype=float32),
#   'probs': array([0.555, 0.204, 0.241], dtype=float32)},
#  {'pred': 1,
#   'referents': ['blue circle', 'blue ellipse', 'blue rectangle'],
#   'utterance': 'circle',
#   'sem': array([0.225, 0.994, 0.   ], dtype=float32),
#   'probs': array([0.253, 0.545, 0.202], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue rectangle', 'blue square'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.882, 0.832], dtype=float32),
#   'probs': array([0.366, 0.325, 0.309], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green ellipse', 'green rectangle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.001], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray square', 'gray circle'],
#   'utterance': 'rectangle',
#   'sem': array([0.974, 0.934, 0.   ], dtype=float32),
#   'probs': array([0.428, 0.411, 0.162], dtype=float32)},
#  {'pred': 1,
#   'referents': ['blue ellipse', 'blue circle', 'blue square'],
#   'utterance': 'ellipse',
#   'sem': array([0.996, 1.   , 0.   ], dtype=float32),
#   'probs': array([0.421, 0.423, 0.156], dtype=float32)},
#  {'pred': 2,
#   'referents': ['red circle', 'red square', 'red ellipse'],
#   'utterance': 'red circle',
#   'sem': array([0.   , 0.   , 0.011], dtype=float32),
#   'probs': array([0.332, 0.332, 0.336], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green circle', 'green ellipse'],
#   'utterance': 'green rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow ellipse', 'yellow rectangle'],
#   'utterance': 'yellow square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue ellipse', 'blue square', 'blue circle'],
#   'utterance': 'ellipse',
#   'sem': array([1.   , 0.   , 0.007], dtype=float32),
#   'probs': array([0.575, 0.212, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue ellipse', 'blue circle'],
#   'utterance': 'rectangle',
#   'sem': array([0.989, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.573, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray rectangle', 'gray square'],
#   'utterance': 'gray ellipse',
#   'sem': array([1.   , 0.831, 0.   ], dtype=float32),
#   'probs': array([0.452, 0.382, 0.166], dtype=float32)},
#  {'pred': 1,
#   'referents': ['green circle', 'green ellipse', 'green rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([0.996, 0.999, 0.   ], dtype=float32),
#   'probs': array([0.421, 0.423, 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow square', 'yellow ellipse'],
#   'utterance': 'circle',
#   'sem': array([0.144, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.366, 0.317, 0.317], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green ellipse', 'green circle'],
#   'utterance': 'green square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red rectangle', 'red square'],
#   'utterance': 'circle',
#   'sem': array([0.199, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.379, 0.311, 0.311], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white rectangle', 'white ellipse'],
#   'utterance': 'circle',
#   'sem': array([0.108, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.358, 0.321, 0.321], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red square', 'red ellipse'],
#   'utterance': 'red circle',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow circle', 'yellow rectangle'],
#   'utterance': 'ellipse',
#   'sem': array([1.  , 0.01, 0.  ], dtype=float32),
#   'probs': array([0.575, 0.214, 0.211], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green ellipse', 'green rectangle'],
#   'utterance': 'square',
#   'sem': array([0.971, 0.   , 0.002], dtype=float32),
#   'probs': array([0.569, 0.215, 0.216], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue circle', 'blue square'],
#   'utterance': 'rectangle',
#   'sem': array([0.992, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.574, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red rectangle', 'red ellipse'],
#   'utterance': 'red square',
#   'sem': array([0.917, 0.497, 0.006], dtype=float32),
#   'probs': array([0.486, 0.319, 0.195], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red circle', 'red ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([0.955, 0.   , 0.001], dtype=float32),
#   'probs': array([0.565, 0.217, 0.218], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white rectangle', 'white square'],
#   'utterance': 'white circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 1,
#   'referents': ['gray circle', 'gray ellipse', 'gray rectangle'],
#   'utterance': 'gray circle',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'white circle', 'white rectangle'],
#   'utterance': 'square',
# ...
#  {'pred': 0,
#   'referents': ['blue square', 'blue ellipse', 'blue circle'],
#   'utterance': 'blue square',
#   'sem': array([0.941, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.562, 0.219, 0.219], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green square', 'green circle'],
#   'utterance': 'green ellipse',
#   'sem': array([1.   , 0.012, 0.967], dtype=float32),
#   'probs': array([0.427, 0.159, 0.414], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray ellipse', 'gray circle'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.001, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 2,
#   'referents': ['green ellipse', 'green rectangle', 'green circle'],
#   'utterance': 'green ellipse',
#   'sem': array([0.765, 0.992, 1.   ], dtype=float32),
#   'probs': array([0.284, 0.357, 0.359], dtype=float32)},
#  {'pred': 2,
#   'referents': ['white ellipse', 'white square', 'white circle'],
#   'utterance': 'white ellipse',
#   'sem': array([0.321, 0.   , 0.985], dtype=float32),
#   'probs': array([0.272, 0.198, 0.53 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray circle', 'gray rectangle'],
#   'utterance': 'gray circle',
#   'sem': array([0.95 , 0.597, 0.   ], dtype=float32),
#   'probs': array([0.479, 0.336, 0.185], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray square', 'gray rectangle'],
#   'utterance': 'gray circle',
#   'sem': array([0.342, 0.082, 0.   ], dtype=float32),
#   'probs': array([0.403, 0.311, 0.286], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue ellipse', 'blue rectangle'],
#   'utterance': 'blue square',
#   'sem': array([1.   , 0.   , 0.862], dtype=float32),
#   'probs': array([0.447, 0.164, 0.389], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue square', 'blue circle', 'blue ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([0.197, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.379, 0.311, 0.311], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow ellipse', 'yellow circle'],
#   'utterance': 'yellow square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray ellipse', 'gray circle'],
#   'utterance': 'square',
#   'sem': array([1.   , 0.   , 0.001], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red ellipse', 'red rectangle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue rectangle', 'blue square'],
#   'utterance': 'blue circle',
#   'sem': array([1.  , 0.68, 0.  ], dtype=float32),
#   'probs': array([0.478, 0.347, 0.176], dtype=float32)},
#  {'pred': 2,
#   'referents': ['red circle', 'red rectangle', 'red ellipse'],
#   'utterance': 'circle',
#   'sem': array([0.999, 0.   , 1.   ], dtype=float32),
#   'probs': array([0.422, 0.155, 0.423], dtype=float32)},
#  {'pred': 1,
#   'referents': ['green rectangle', 'green square', 'green circle'],
#   'utterance': 'rectangle',
#   'sem': array([0.992, 0.994, 0.   ], dtype=float32),
#   'probs': array([0.421, 0.422, 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green ellipse', 'green rectangle'],
#   'utterance': 'circle',
#   'sem': array([0.987, 0.031, 0.003], dtype=float32),
#   'probs': array([0.569, 0.219, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue ellipse', 'blue circle', 'blue square'],
#   'utterance': 'ellipse',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red square', 'red ellipse'],
#   'utterance': 'red circle',
#   'sem': array([0.998, 0.   , 0.001], dtype=float32),
#   'probs': array([0.575, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue ellipse', 'blue rectangle', 'blue circle'],
#   'utterance': 'blue ellipse',
#   'sem': array([1.   , 0.094, 0.936], dtype=float32),
#   'probs': array([0.427, 0.172, 0.401], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white square', 'white circle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow rectangle', 'yellow circle'],
#   'utterance': 'ellipse',
#   'sem': array([1.   , 0.   , 0.195], dtype=float32),
#   'probs': array([0.551, 0.203, 0.246], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red circle', 'red ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue ellipse', 'blue square'],
#   'utterance': 'square',
#   'sem': array([0.994, 0.   , 0.18 ], dtype=float32),
#   'probs': array([0.551, 0.204, 0.244], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow circle', 'yellow ellipse'],
#   'utterance': 'yellow square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray ellipse', 'gray rectangle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red ellipse', 'red rectangle'],
#   'utterance': 'red square',
#   'sem': array([1.   , 0.   , 0.208], dtype=float32),
#   'probs': array([0.549, 0.202, 0.249], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white square', 'white rectangle'],
#   'utterance': 'white circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 2,
#   'referents': ['white ellipse', 'white square', 'white circle'],
#   'utterance': 'white ellipse',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue ellipse', 'blue rectangle'],
#   'utterance': 'circle',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow rectangle', 'yellow ellipse'],
#   'utterance': 'circle',
#   'sem': array([0.823, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.532, 0.234, 0.234], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red square', 'red ellipse'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue square', 'blue rectangle'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.233, 0.   ], dtype=float32),
#   'probs': array([0.546, 0.254, 0.201], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue ellipse', 'blue circle'],
#   'utterance': 'rectangle',
#   'sem': array([0.98, 0.  , 0.  ], dtype=float32),
#   'probs': array([0.571, 0.214, 0.214], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow circle', 'yellow square'],
#   'utterance': 'yellow rectangle',
#   'sem': array([0.007, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.335, 0.333, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue rectangle', 'blue square'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.004, 0.258], dtype=float32),
#   'probs': array([0.542, 0.2  , 0.258], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue square', 'blue ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([0.994, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.575, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green rectangle', 'green square'],
#   'utterance': 'green ellipse',
#   'sem': array([0.998, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 2,
#   'referents': ['green ellipse', 'green rectangle', 'green circle'],
#   'utterance': 'green circle',
#   'sem': array([0.997, 0.   , 0.999], dtype=float32),
#   'probs': array([0.422, 0.156, 0.423], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow ellipse', 'yellow square'],
#   'utterance': 'circle',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red circle', 'red square'],
#   'utterance': 'rectangle',
#   'sem': array([0.108, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.358, 0.321, 0.321], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'white circle', 'white square'],
#   'utterance': 'white ellipse',
#   'sem': array([1.   , 1.   , 0.001], dtype=float32),
#   'probs': array([0.422, 0.422, 0.156], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow square', 'yellow rectangle'],
#   'utterance': 'yellow circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow ellipse', 'yellow square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.039], dtype=float32),
#   'probs': array([0.571, 0.21 , 0.219], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray square', 'gray ellipse'],
#   'utterance': 'circle',
#   'sem': array([0.821, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.532, 0.234, 0.234], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue ellipse', 'blue circle', 'blue square'],
#   'utterance': 'blue ellipse',
#   'sem': array([1.   , 1.   , 0.129], dtype=float32),
#   'probs': array([0.413, 0.413, 0.173], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow ellipse', 'yellow rectangle'],
#   'utterance': 'yellow square',
#   'sem': array([1.   , 0.   , 0.094], dtype=float32),
#   'probs': array([0.564, 0.208, 0.228], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white square', 'white rectangle'],
#   'utterance': 'circle',
#   'sem': array([0.05, 0.  , 0.  ], dtype=float32),
#   'probs': array([0.344, 0.328, 0.328], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'red rectangle', 'red ellipse'],
#   'utterance': 'red circle',
#   'sem': array([1.   , 0.   , 0.986], dtype=float32),
#   'probs': array([0.425, 0.156, 0.419], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white ellipse', 'white square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'gray ellipse', 'gray square'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.031, 0.023], dtype=float32),
#   'probs': array([0.57 , 0.216, 0.214], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray ellipse', 'gray circle'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.011, 0.   ], dtype=float32),
#   'probs': array([0.575, 0.214, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white ellipse', 'white square'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.001, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray rectangle', 'gray circle'],
#   'utterance': 'gray square',
#   'sem': array([0.999, 0.993, 0.   ], dtype=float32),
#   'probs': array([0.423, 0.421, 0.156], dtype=float32)},
#  {'pred': 2,
#   'referents': ['red circle', 'red rectangle', 'red ellipse'],
#   'utterance': 'circle',
#   'sem': array([1.   , 0.001, 1.   ], dtype=float32),
#   'probs': array([0.422, 0.156, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'gray ellipse', 'gray circle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white circle', 'white square'],
#   'utterance': 'rectangle',
#   'sem': array([0.995, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.575, 0.213, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray ellipse', 'gray circle', 'gray square'],
#   'utterance': 'ellipse',
#   'sem': array([0.982, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.572, 0.214, 0.214], dtype=float32)},
#  {'pred': 2,
#   'referents': ['red rectangle', 'red ellipse', 'red square'],
#   'utterance': 'red rectangle',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red square', 'red circle'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.976, 0.   ], dtype=float32),
#   'probs': array([0.427, 0.416, 0.157], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'yellow square', 'yellow circle'],
#   'utterance': 'rectangle',
#   'sem': array([1., 1., 0.], dtype=float32),
#   'probs': array([0.422, 0.422, 0.155], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green circle', 'green square', 'green rectangle'],
#   'utterance': 'green circle',
#   'sem': array([1.   , 0.027, 0.001], dtype=float32),
#   'probs': array([0.573, 0.217, 0.211], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green ellipse', 'green circle', 'green square'],
#   'utterance': 'green ellipse',
#   'sem': array([1.   , 0.043, 0.057], dtype=float32),
#   'probs': array([0.564, 0.217, 0.22 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue rectangle', 'blue ellipse', 'blue circle'],
#   'utterance': 'blue square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 1,
#   'referents': ['gray circle', 'gray ellipse', 'gray square'],
#   'utterance': 'circle',
#   'sem': array([0.838, 0.992, 0.001], dtype=float32),
#   'probs': array([0.385, 0.449, 0.167], dtype=float32)},
#  {'pred': 1,
#   'referents': ['green ellipse', 'green circle', 'green rectangle'],
#   'utterance': 'circle',
#   'sem': array([0.266, 0.721, 0.001], dtype=float32),
#   'probs': array([0.299, 0.471, 0.23 ], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green ellipse', 'green circle'],
#   'utterance': 'green rectangle',
#   'sem': array([0.999, 0.005, 0.   ], dtype=float32),
#   'probs': array([0.575, 0.213, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow ellipse', 'yellow rectangle', 'yellow circle'],
#   'utterance': 'ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red square', 'red circle', 'red rectangle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray circle', 'gray ellipse', 'gray square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red ellipse', 'red square'],
#   'utterance': 'red rectangle',
#   'sem': array([1.   , 0.   , 0.569], dtype=float32),
#   'probs': array([0.496, 0.182, 0.322], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'white ellipse', 'white square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'red circle', 'red ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1.   , 0.   , 0.056], dtype=float32),
#   'probs': array([0.569, 0.209, 0.221], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'white circle', 'white ellipse'],
#   'utterance': 'white square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow square', 'yellow ellipse', 'yellow circle'],
#   'utterance': 'yellow square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  ...]

# %% [markdown]
# ## in `shape-needed`, what are examples where color is mentioned?

# %%
both_filter_func = lambda x: any([s in x['utterance'] for s in eval_utils.SHAPES]) and any([c in x['utterance'] for c in eval_utils.COLORS])

# %%
filtered_shape_qa = list(filter(both_filter_func, shape_qa))
filtered_shape_qa[:8]
# Out:
# [{'pred': 0,
#   'referents': ['green ellipse', 'green rectangle', 'green square'],
#   'utterance': 'green ellipse',
#   'sem': array([0.999, 0.   , 0.002], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'blue rectangle', 'blue square'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.003, 0.999], dtype=float32),
#   'probs': array([0.422, 0.156, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'green ellipse', 'green rectangle'],
#   'utterance': 'green square',
#   'sem': array([1., 0., 1.], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow circle', 'yellow square', 'yellow rectangle'],
#   'utterance': 'yellow circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 2,
#   'referents': ['green ellipse', 'green square', 'green circle'],
#   'utterance': 'green circle',
#   'sem': array([0.986, 0.034, 1.   ], dtype=float32),
#   'probs': array([0.417, 0.161, 0.423], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green rectangle', 'green circle', 'green ellipse'],
#   'utterance': 'green rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'red square', 'red rectangle'],
#   'utterance': 'red ellipse',
#   'sem': array([1.   , 0.   , 0.005], dtype=float32),
#   'probs': array([0.575, 0.212, 0.213], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white rectangle', 'white square', 'white circle'],
#   'utterance': 'white rectangle',
#   'sem': array([1.   , 0.739, 0.   ], dtype=float32),
#   'probs': array([0.468, 0.36 , 0.172], dtype=float32)}]

# %%
num_overmod_per_combo = Counter(map(lambda x:x['referents'][0], filtered_shape_qa))
num_overmod_per_combo.most_common()
# Out:
# [('red ellipse', 128),
#  ('green circle', 122),
#  ('blue ellipse', 118),
#  ('red circle', 117),
#  ('white rectangle', 115),
#  ('blue square', 112),
#  ('green ellipse', 107),
#  ('yellow ellipse', 107),
#  ('blue circle', 106),
#  ('white square', 94),
#  ('gray ellipse', 91),
#  ('gray circle', 89),
#  ('white ellipse', 88),
#  ('yellow square', 86),
#  ('green square', 83),
#  ('green rectangle', 79),
#  ('red rectangle', 72),
#  ('red square', 71),
#  ('white circle', 71),
#  ('gray square', 70),
#  ('yellow rectangle', 64),
#  ('yellow circle', 61),
#  ('blue rectangle', 52),
#  ('gray rectangle', 51)]

# %% [markdown]
# ### Aggregate all speakers

# %% [markdown]
# #### Overmodification

# %%
perc_overmod_per_shape = {}
perc_overmod_per_color = {}
for speaker_results in eval_results:
    speaker_shape_qa = eval_utils.qualitative_analysis('shape-needed', speaker_results['val'], speaker_results['all_referents'], num_examples=-1)
    speaker_overmod_shape_qa = list(filter(both_filter_func, speaker_shape_qa))
    
    num_total_per_shape = Counter(map(lambda x:x['referents'][0].split()[1], speaker_shape_qa))
    num_overmod_per_shape = Counter(map(lambda x:x['referents'][0].split()[1], speaker_overmod_shape_qa))
    for shape, num_overmod in num_overmod_per_shape.items():
        num_total = num_total_per_shape[shape]
        if shape not in perc_overmod_per_shape: perc_overmod_per_shape[shape] = []
        perc_overmod_per_shape[shape].append(num_overmod / num_total)
    
    num_total_per_color = Counter(map(lambda x:x['referents'][0].split()[0], speaker_shape_qa))
    num_overmod_per_color = Counter(map(lambda x:x['referents'][0].split()[0], speaker_overmod_shape_qa))
    for color, num_overmod in num_overmod_per_color.items():
        num_total = num_total_per_color[color]
        if color not in perc_overmod_per_color: perc_overmod_per_color[color] = []
        perc_overmod_per_color[color].append(num_overmod / num_total)

# %%
for shape in perc_overmod_per_shape:
    perc_overmod_per_shape[shape] = (np.mean(perc_overmod_per_shape[shape]), np.std(perc_overmod_per_shape[shape]))

# %%
{key: np.round(val, 4) for key, val in sorted(perc_overmod_per_shape.items(), key=lambda x: x[1][0], reverse=True)}
# Out:
# {'ellipse': array([0.4791, 0.0209]),
#  'circle': array([0.4468, 0.0345]),
#  'square': array([0.3538, 0.038 ]),
#  'rectangle': array([0.3299, 0.027 ])}

# %%
for color in perc_overmod_per_color:
    perc_overmod_per_color[color] = (np.mean(perc_overmod_per_color[color]), np.std(perc_overmod_per_color[color]))

# %%
{key: np.round(val, 4) for key, val in sorted(perc_overmod_per_color.items(), key=lambda x: x[1][0], reverse=True)}
# Out:
# {'red': array([0.456 , 0.0371]),
#  'green': array([0.4309, 0.0304]),
#  'blue': array([0.4272, 0.0406]),
#  'white': array([0.3908, 0.021 ]),
#  'yellow': array([0.3653, 0.016 ]),
#  'gray': array([0.3488, 0.0257])}

# %% [markdown]
# #### Accuracy by shape

# %%
accuracy_per_shape = {shape: [] for shape in perc_overmod_per_shape}
for speaker_results in eval_results:
    speaker_shape_qa = eval_utils.qualitative_analysis('shape-needed', speaker_results['val'], speaker_results['all_referents'], num_examples=-1)
    for shape in accuracy_per_shape:
        curr_shape_qa = [e for e in speaker_shape_qa if e['referents'][0].split()[1] == shape]
        num_correct = len([e for e in curr_shape_qa if e['pred'] == 0])
        acc = num_correct / len(curr_shape_qa)
        accuracy_per_shape[shape].append(acc)
    

for shape in accuracy_per_shape:
    accuracy_per_shape[shape] = (np.mean(accuracy_per_shape[shape]), np.std(accuracy_per_shape[shape]))

# %%
accuracy_per_shape
# Out:
# {'ellipse': (0.7838989739542226, 0.007707375290123883),
#  'circle': (0.8721864951768488, 0.006349973523514955),
#  'square': (0.93091202582728, 0.0012079604154233523),
#  'rectangle': (0.9169599999999999, 0.003799789467852133)}

# %% [markdown]
# ## in `color-needed`, what are examples where shape is mentioned

# %%
# in color-needed, what are examples where color is mentioned
filtered_color_qa = list(filter(both_filter_func, color_qa))
filtered_color_qa[:8]
# Out:
# [{'pred': 0,
#   'referents': ['white rectangle', 'blue rectangle', 'green rectangle'],
#   'utterance': 'white rectangle',
#   'sem': array([0., 0., 0.], dtype=float32),
#   'probs': array([0.333, 0.333, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['blue circle', 'red circle', 'green circle'],
#   'utterance': 'blue circle',
#   'sem': array([1.   , 0.599, 0.   ], dtype=float32),
#   'probs': array([0.491, 0.329, 0.181], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white square', 'blue square', 'red square'],
#   'utterance': 'white square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'green ellipse', 'yellow ellipse'],
#   'utterance': 'white ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'blue rectangle', 'white rectangle'],
#   'utterance': 'yellow rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'blue square', 'red square'],
#   'utterance': 'gray square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 2,
#   'referents': ['gray square', 'blue square', 'white square'],
#   'utterance': 'gray square',
#   'sem': array([0.999, 0.   , 1.   ], dtype=float32),
#   'probs': array([0.422, 0.155, 0.422], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'red square', 'blue square'],
#   'utterance': 'gray square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)}]

# %%
Counter(map(lambda x:x['referents'][0], filtered_color_qa)).most_common()
# Out:
# [('gray square', 53),
#  ('gray rectangle', 51),
#  ('white ellipse', 35),
#  ('white circle', 18),
#  ('white square', 14),
#  ('white rectangle', 13),
#  ('yellow circle', 8),
#  ('red square', 7),
#  ('gray ellipse', 7),
#  ('green rectangle', 6),
#  ('yellow square', 6),
#  ('gray circle', 5),
#  ('yellow ellipse', 4),
#  ('red rectangle', 4),
#  ('blue rectangle', 3),
#  ('blue square', 3),
#  ('yellow rectangle', 2),
#  ('red circle', 2),
#  ('blue circle', 1),
#  ('green ellipse', 1),
#  ('red ellipse', 1),
#  ('green square', 1)]

# %% [markdown]
# ## in `either-okay`

# %% [markdown]
# ### mentions color, no shape

# %%
color_only_filter_func = lambda x: any([c in x['utterance'] for c in eval_utils.COLORS]) and all([s not in x['utterance'] for s in eval_utils.SHAPES])

color_only_filtered_qa = list(filter(color_only_filter_func, either_qa))

Counter(map(lambda x:x['referents'][0], color_only_filtered_qa)).most_common()
# Out:
# [('blue ellipse', 222),
#  ('blue circle', 220),
#  ('green circle', 210),
#  ('red circle', 204),
#  ('green rectangle', 201),
#  ('red ellipse', 197),
#  ('green ellipse', 197),
#  ('yellow ellipse', 191),
#  ('green square', 187),
#  ('yellow circle', 186),
#  ('red rectangle', 181),
#  ('gray ellipse', 176),
#  ('blue square', 174),
#  ('blue rectangle', 167),
#  ('white circle', 167),
#  ('red square', 167),
#  ('yellow rectangle', 160),
#  ('white ellipse', 160),
#  ('white rectangle', 153),
#  ('yellow square', 144),
#  ('gray circle', 142),
#  ('white square', 137),
#  ('gray rectangle', 126),
#  ('gray square', 85)]

# %%
color_only_filtered_qa[:8]
# Out:
# [{'pred': 0,
#   'referents': ['yellow ellipse', 'gray square', 'white rectangle'],
#   'utterance': 'yellow shape',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'green ellipse', 'red ellipse'],
#   'utterance': 'yellow shape',
#   'sem': array([1.   , 0.001, 0.   ], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'gray ellipse', 'yellow rectangle'],
#   'utterance': 'green shape',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red circle', 'gray ellipse', 'green ellipse'],
#   'utterance': 'red',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'gray ellipse', 'gray circle'],
#   'utterance': 'red shape',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['yellow rectangle', 'blue ellipse', 'white circle'],
#   'utterance': 'yellow',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray rectangle', 'red square', 'blue square'],
#   'utterance': 'gray shape',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red ellipse', 'white square', 'gray rectangle'],
#   'utterance': 'red',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)}]

# %% [markdown]
# ### mentions shape, but no color

# %%
shape_only_filter_func = lambda x: any([s in x['utterance'] for s in eval_utils.SHAPES]) and all([c not in x['utterance'] for c in eval_utils.COLORS])

shape_only_filtered_qa = list(filter(shape_only_filter_func, either_qa))

Counter(map(lambda x:x['referents'][0], shape_only_filtered_qa)).most_common()
# Out:
# [('gray square', 46),
#  ('gray rectangle', 41),
#  ('white square', 34),
#  ('green square', 28),
#  ('yellow square', 26),
#  ('yellow rectangle', 21),
#  ('white circle', 20),
#  ('red square', 18),
#  ('blue rectangle', 14),
#  ('white rectangle', 14),
#  ('white ellipse', 13),
#  ('blue square', 11),
#  ('red rectangle', 10),
#  ('gray circle', 7),
#  ('green rectangle', 6),
#  ('yellow circle', 6),
#  ('yellow ellipse', 5),
#  ('red circle', 3),
#  ('green circle', 2),
#  ('gray ellipse', 2)]

# %%
shape_only_filtered_qa[:8]
# Out:
# [{'pred': 0,
#   'referents': ['blue square', 'white ellipse', 'gray circle'],
#   'utterance': 'square',
#   'sem': array([0.905, 0.   , 0.004], dtype=float32),
#   'probs': array([0.552, 0.223, 0.224], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'white ellipse', 'blue circle'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['gray square', 'blue ellipse', 'blue circle'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'green square', 'gray square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['red rectangle', 'blue circle', 'blue ellipse'],
#   'utterance': 'rectangle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['green square', 'gray ellipse', 'white ellipse'],
#   'utterance': 'square',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'red square', 'yellow square'],
#   'utterance': 'circle',
#   'sem': array([0.997, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.575, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'gray rectangle', 'red square'],
#   'utterance': 'circle',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)}]

# %% [markdown]
# ## mentions both color and shape

# %%
both_present_filter_func = lambda x: any([s in x['utterance'] for s in eval_utils.SHAPES]) and any([c in x['utterance'] for c in eval_utils.COLORS])

both_present_filtered_qa = list(filter(both_present_filter_func, either_qa))

Counter(map(lambda x:x['referents'][0], shape_only_filtered_qa)).most_common()
# Out:
# [('gray square', 46),
#  ('gray rectangle', 41),
#  ('white square', 34),
#  ('green square', 28),
#  ('yellow square', 26),
#  ('yellow rectangle', 21),
#  ('white circle', 20),
#  ('red square', 18),
#  ('blue rectangle', 14),
#  ('white rectangle', 14),
#  ('white ellipse', 13),
#  ('blue square', 11),
#  ('red rectangle', 10),
#  ('gray circle', 7),
#  ('green rectangle', 6),
#  ('yellow circle', 6),
#  ('yellow ellipse', 5),
#  ('red circle', 3),
#  ('green circle', 2),
#  ('gray ellipse', 2)]

# %%
qa = eval_utils.qualitative_analysis('both-needed', eval_results[speaker_idx]['val'], eval_results[speaker_idx]['all_referents'], num_examples=-1)

# %%
filter_func = lambda x: 'white' in x['referents'][0] and 'gray' in x['utterance']

# %%
list(filter(filter_func, qa))
# Out:
# [{'pred': 2,
#   'referents': ['white circle', 'blue circle', 'white ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([0.   , 0.   , 0.991], dtype=float32),
#   'probs': array([0.213, 0.213, 0.574], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'green ellipse', 'white circle'],
#   'utterance': 'gray ellipse',
#   'sem': array([1.   , 0.644, 0.   ], dtype=float32),
#   'probs': array([0.484, 0.339, 0.178], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'blue circle', 'white ellipse'],
#   'utterance': 'gray ellipse',
#   'sem': array([0.041, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.342, 0.329, 0.329], dtype=float32)},
#  {'pred': 2,
#   'referents': ['white circle', 'yellow circle', 'white ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([0., 0., 1.], dtype=float32),
#   'probs': array([0.212, 0.212, 0.576], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'yellow ellipse', 'white square'],
#   'utterance': 'gray ellipse',
#   'sem': array([0., 0., 0.], dtype=float32),
#   'probs': array([0.333, 0.333, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'blue ellipse', 'white circle'],
#   'utterance': 'gray ellipse',
#   'sem': array([1., 0., 0.], dtype=float32),
#   'probs': array([0.576, 0.212, 0.212], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'red circle', 'white ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([0.096, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.355, 0.322, 0.322], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'yellow circle', 'white ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([0., 0., 0.], dtype=float32),
#   'probs': array([0.333, 0.333, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'red ellipse', 'white circle'],
#   'utterance': 'gray ellipse',
#   'sem': array([0., 0., 0.], dtype=float32),
#   'probs': array([0.333, 0.333, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'blue circle', 'white ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([0.403, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.428, 0.286, 0.286], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'red circle', 'white ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([0.613, 0.   , 0.   ], dtype=float32),
#   'probs': array([0.48, 0.26, 0.26], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white circle', 'blue circle', 'white ellipse'],
#   'utterance': 'gray circle',
#   'sem': array([0., 0., 0.], dtype=float32),
#   'probs': array([0.333, 0.333, 0.333], dtype=float32)},
#  {'pred': 0,
#   'referents': ['white ellipse', 'green ellipse', 'white circle'],
#   'utterance': 'gray ellipse',
#   'sem': array([1.   , 0.   , 0.202], dtype=float32),
#   'probs': array([0.55 , 0.202, 0.248], dtype=float32)}]
